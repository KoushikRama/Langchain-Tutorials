# %%
pip install langchain langchain-huggingface python-dotenv langchain-groq
# Out:
# Requirement already satisfied: langchain in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-huggingface in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (1.2.0)
# Requirement already satisfied: python-dotenv in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-groq in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain) (1.2.15)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain) (1.0.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.8)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-huggingface) (0.36.2)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2026.2.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: colorama in c:\users\koush\desktop\langchain-tutorials\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from dotenv import load_dotenv

load_dotenv()

base_llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    task="conversational",
    temperature=0.7,
    max_new_tokens=150
)

llm = ChatHuggingFace(llm=base_llm)

response = llm.invoke("Explain LangChain in simple terms.")
print(response)
# Out:
# content='LangChain is a framework for building **AI-powered applications** that connect different tools, data sources, and AI models (like chatbots or assistants) in a flexible way. Think of it as a **"chain"** of components that work together to create more intelligent and useful AI tools.\n\n### Simple Breakdown:\n1. **Connects AI with Real Data**\n   - Most AI models (e.g., LLMs like me) work with text they’ve been trained on but can’t directly access live data (databases, APIs, the internet).\n   - LangChain acts as a bridge to let AI **fetch, process, and use real-time information** (e.g., your emails, code repositories, or up-to-date articles).\n\n2' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 150, 'prompt_tokens': 545, 'total_tokens': 695}, 'model_name': 'mistralai/Mistral-7B-Instruct-v0.2', 'system_fingerprint': None, 'finish_reason': 'length', 'logprobs': None} id='lc_run--019c90e6-e35b-75f1-9f24-28dc306b6951-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 545, 'output_tokens': 150, 'total_tokens': 695}

# %%
print(response.content)
# Out:
# LangChain is a framework for building **AI-powered applications** that connect different tools, data sources, and AI models (like chatbots or assistants) in a flexible way. Think of it as a **"chain"** of components that work together to create more intelligent and useful AI tools.
#
# ### Simple Breakdown:
# 1. **Connects AI with Real Data**
#    - Most AI models (e.g., LLMs like me) work with text they’ve been trained on but can’t directly access live data (databases, APIs, the internet).
#    - LangChain acts as a bridge to let AI **fetch, process, and use real-time information** (e.g., your emails, code repositories, or up-to-date articles).
#
# 2

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.7
)

response = llm.invoke("Explain LangChain in simple terms.")
print(response)
# Out:
# content='LangChain is an open-source Python library that allows developers to build conversational AI systems. It\'s designed to work with large language models like those used in chatbots, virtual assistants, and other applications that involve natural language processing (NLP).\n\nImagine you\'re building a conversational AI system, like a chatbot that can:\n\n1. Understand what a user says\n2. Respond with an answer or ask a question\n3. Remember the conversation history\n\nLangChain makes it easier to build these types of systems by providing a set of tools and APIs that allow you to:\n\n1. **Store and retrieve conversation history**: LangChain provides a way to store the conversation history in memory or in a database, so your chatbot can remember what was said before.\n2. **Chain together multiple language models**: LangChain allows you to combine multiple language models, like a question-answering model and a text-generation model, to create a more powerful conversational AI system.\n3. **Control the flow of the conversation**: LangChain provides a way to control the flow of the conversation, like asking follow-up questions or prompting the user for more information.\n\nBy using LangChain, developers can build more sophisticated conversational AI systems that can understand and respond to user input in a more natural and human-like way.\n\nTo illustrate this, consider a simple example: a chatbot that can:\n\n* Understand user input (e.g., "I\'m tired")\n* Respond with a relevant answer (e.g., "Would you like to take a break?")\n* Ask follow-up questions (e.g., "Do you want to listen to some calming music?")\n\nLangChain makes it easier to build this type of system by providing a set of tools and APIs that allow you to control the flow of the conversation and combine multiple language models to create a more powerful chatbot.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 374, 'prompt_tokens': 43, 'total_tokens': 417, 'completion_time': 0.594168387, 'completion_tokens_details': None, 'prompt_time': 0.006864604, 'prompt_tokens_details': None, 'queue_time': 0.036977305, 'total_time': 0.601032991}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_66c49b4aa6', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c90e7-1732-7481-91bc-e4c904b556fc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 374, 'total_tokens': 417}

# %%
print(response.content)
# Out:
# LangChain is an open-source Python library that allows developers to build conversational AI systems. It's designed to work with large language models like those used in chatbots, virtual assistants, and other applications that involve natural language processing (NLP).
#
# Imagine you're building a conversational AI system, like a chatbot that can:
#
# 1. Understand what a user says
# 2. Respond with an answer or ask a question
# 3. Remember the conversation history
#
# LangChain makes it easier to build these types of systems by providing a set of tools and APIs that allow you to:
#
# 1. **Store and retrieve conversation history**: LangChain provides a way to store the conversation history in memory or in a database, so your chatbot can remember what was said before.
# 2. **Chain together multiple language models**: LangChain allows you to combine multiple language models, like a question-answering model and a text-generation model, to create a more powerful conversational AI system.
# 3. **Control the flow of the conversation**: LangChain provides a way to control the flow of the conversation, like asking follow-up questions or prompting the user for more information.
#
# By using LangChain, developers can build more sophisticated conversational AI systems that can understand and respond to user input in a more natural and human-like way.
#
# To illustrate this, consider a simple example: a chatbot that can:
#
# * Understand user input (e.g., "I'm tired")
# * Respond with a relevant answer (e.g., "Would you like to take a break?")
# * Ask follow-up questions (e.g., "Do you want to listen to some calming music?")
#
# LangChain makes it easier to build this type of system by providing a set of tools and APIs that allow you to control the flow of the conversation and combine multiple language models to create a more powerful chatbot.
